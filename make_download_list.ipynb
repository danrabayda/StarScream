# %%
import numpy as np
import pandas as pd
import json
import os

# %%
# from https://research.google.com/audioset/download_strong.html
X = pd.read_csv('audioset_train_strong.tsv', sep='\t')

# %%
# from https://github.com/audioset/ontology
with open("ontology.json", "r") as read_file:
    data = json.load(read_file)

# %%
def translate(x): #see ontology.json and this will make sense. data is a list of dictionaries so item is one dictionary
    try:
        return next(item for item in data if item["id"] == x['label'])['name'].replace(" ","").replace(",","_")
    except:
        return 'N/A'

# %%
next(item for item in data if item["id"] == '/m/0cmf2')['name'].replace(" ","").replace(",","_") #a demo of translate's operation
# Out:
# 'Fixed-wingaircraft_airplane'

# %%
X['time_interval'] = X.apply(lambda row: (row['start_time_seconds'], row['end_time_seconds']), axis=1) #the time intervals are listed in the tsv file next to their corresponding ids. I assume it is easier to get the info from this tsv than it is to split each youtube link name (in json) into parts for it
X['link'] = X.apply(lambda row: "youtu.be/" + "_".join(row['segment_id'].split('_')[:-1]), axis=1) #just adds the link to youtube plus the segment id from the tsv to the last column of our X df
X.head()
# Out:
#           segment_id  start_time_seconds  end_time_seconds       label  \
# 0  b0RFKhbpFJA_30000               0.000            10.000  /m/03m9d0z
# 1  b0RFKhbpFJA_30000               4.753             5.720   /m/05zppz
# 2  b0RFKhbpFJA_30000               0.000            10.000  /m/07pjwq1
# 3  b0RFKhbpFJA_30000               6.899             7.010  /m/07qjznt
# 4  b0RFKhbpFJA_30000               8.534             9.156  /t/dd00092
#
#     time_interval                  link
# 0     (0.0, 10.0)  youtu.be/b0RFKhbpFJA
# 1   (4.753, 5.72)  youtu.be/b0RFKhbpFJA
# 2     (0.0, 10.0)  youtu.be/b0RFKhbpFJA
# 3   (6.899, 7.01)  youtu.be/b0RFKhbpFJA
# 4  (8.534, 9.156)  youtu.be/b0RFKhbpFJA

# %%
# this takes a long time
X['name'] = X.apply(translate, axis=1) #gets the names in a reasonable format out of the json and add that to the end too
X.head()
# Out:
#           segment_id  start_time_seconds  end_time_seconds       label  \
# 0  b0RFKhbpFJA_30000               0.000            10.000  /m/03m9d0z
# 1  b0RFKhbpFJA_30000               4.753             5.720   /m/05zppz
# 2  b0RFKhbpFJA_30000               0.000            10.000  /m/07pjwq1
# 3  b0RFKhbpFJA_30000               6.899             7.010  /m/07qjznt
# 4  b0RFKhbpFJA_30000               8.534             9.156  /t/dd00092
#
#     time_interval                  link                    name
# 0     (0.0, 10.0)  youtu.be/b0RFKhbpFJA                    Wind
# 1   (4.753, 5.72)  youtu.be/b0RFKhbpFJA  Malespeech_manspeaking
# 2     (0.0, 10.0)  youtu.be/b0RFKhbpFJA                    Buzz
# 3   (6.899, 7.01)  youtu.be/b0RFKhbpFJA                    Tick
# 4  (8.534, 9.156)  youtu.be/b0RFKhbpFJA   Windnoise(microphone)

# %%
classes = ["Motorboat_speedboat",
"Racecar_autoracing",
"Carpassingby",
"Tiresqueal",
"Caralarm",
"Vehiclehorn_carhorn_honking",
"Airbrake",
"Airhorn_truckhorn",
"Bus",
"Motorcycle",
"Trafficnoise_roadwaynoise",
"Railroadcar_trainwagon",
"Trainwheelssquealing",
"Helicopter",
"Fixed-wingaircraft_airplane",
"Lightengine(highfrequency)",
"Mediumengine(midfrequency)",
"Heavyengine(lowfrequency)"]

# %%
Y = X[[X['name'].values[i] in classes for i in range(len(X))]]
Y.head()
# Out:
#              segment_id  start_time_seconds  end_time_seconds       label  \
# 255   3zOfKHtXxws_30000               4.181              4.75   /m/02mfyn
# 269   -x1F1bVe6JM_30000               1.809             10.00  /t/dd00066
# 376   YRS0I6WrjOs_30000               0.000             10.00  /t/dd00066
# 466  18PPxEB6Cb4_540000               0.000             10.00   /m/02rlv9
# 476   1MjtxzIAz4s_30000               0.000             10.00  /t/dd00065
#
#      time_interval                  link                        name
# 255  (4.181, 4.75)  youtu.be/3zOfKHtXxws                    Caralarm
# 269  (1.809, 10.0)  youtu.be/-x1F1bVe6JM  Mediumengine(midfrequency)
# 376    (0.0, 10.0)  youtu.be/YRS0I6WrjOs  Mediumengine(midfrequency)
# 466    (0.0, 10.0)  youtu.be/18PPxEB6Cb4         Motorboat_speedboat
# 476    (0.0, 10.0)  youtu.be/1MjtxzIAz4s  Lightengine(highfrequency)

# %%
Y.groupby('name').agg({'link':len})
# Out:
#                              link
# name
# Airbrake                      503
# Airhorn_truckhorn             926
# Bus                           365
# Caralarm                      630
# Carpassingby                  390
# Fixed-wingaircraft_airplane   243
# Heavyengine(lowfrequency)     583
# Helicopter                    396
# Lightengine(highfrequency)    153
# Mediumengine(midfrequency)   2142
# Motorboat_speedboat           539
# Motorcycle                    646
# Racecar_autoracing            515
# Railroadcar_trainwagon        141
# Tiresqueal                   1061
# Trafficnoise_roadwaynoise     710
# Trainwheelssquealing          889
# Vehiclehorn_carhorn_honking  1930

# %%
df = Y.groupby('segment_id').agg({'time_interval': list, 'name': list, 'link': np.unique})
df.to_csv('clean_download.csv')

# %%
x=lambda a:a+2
x(3)
# Out:
# 5
